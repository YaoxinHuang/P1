# %%
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import sys, torch, torchvision, os
sys.path.insert(0, r'D:/Course/P1/code')
from matplotlib import pyplot as plt
from data.fft import *
from data.FAZ import *
from PIL import Image

# %%
img1 = np.asarray(Image.open(r'../../FAZ/domain1/train/imgs/001_M_1.png')) / 255.
img2 = np.asarray(Image.open(r'D:\Course\P1\FAZ\Domain2\train\imgs\10302.png')) / 255.
# domain_amps = [domain1, domain2, domain3, domain4, domain5]

# %%
plt.figure()
new_img1 = np.clip(domain_shift(img1, img2), 0, 1)
plt.subplot(1,3,1)
plt.imshow(img1)
plt.subplot(1,3,2)
plt.imshow(img2)
plt.subplot(1,3,3)
plt.imshow(new_img1)
plt.show()
# Out:
# False

# %%
import glob
i = 1
glob.glob(f'../../FAZ/Domain{i}/train/imgs/*.png')
# Out:
# ['../../FAZ/Domain1/train/imgs\\001_M_1.png',
#  '../../FAZ/Domain1/train/imgs\\001_N_1.png',
#  '../../FAZ/Domain1/train/imgs\\002_D_10.png',
#  '../../FAZ/Domain1/train/imgs\\002_M_10.png',
#  '../../FAZ/Domain1/train/imgs\\003_D_100.png',
#  '../../FAZ/Domain1/train/imgs\\003_M_100.png',
#  '../../FAZ/Domain1/train/imgs\\003_N_11.png',
#  '../../FAZ/Domain1/train/imgs\\004_D_101.png',
#  '../../FAZ/Domain1/train/imgs\\004_N_12.png',
#  '../../FAZ/Domain1/train/imgs\\005_D_102.png',
#  '../../FAZ/Domain1/train/imgs\\005_M_102.png',
#  '../../FAZ/Domain1/train/imgs\\005_N_13.png',
#  '../../FAZ/Domain1/train/imgs\\006_M_103.png',
#  '../../FAZ/Domain1/train/imgs\\006_N_14.png',
#  '../../FAZ/Domain1/train/imgs\\007_D_104.png',
#  '../../FAZ/Domain1/train/imgs\\007_M_104.png',
#  '../../FAZ/Domain1/train/imgs\\008_D_105.png',
#  '../../FAZ/Domain1/train/imgs\\008_M_105.png',
#  '../../FAZ/Domain1/train/imgs\\008_N_16.png',
#  '../../FAZ/Domain1/train/imgs\\009_D_106.png',
# ...
